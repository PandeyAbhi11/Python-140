# %% [markdown]
# <a href="https://colab.research.google.com/github/PandeyAbhi11/Python-140/blob/main/Copy_of_PythonProgram_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python")
# Out:
# Hello Python
